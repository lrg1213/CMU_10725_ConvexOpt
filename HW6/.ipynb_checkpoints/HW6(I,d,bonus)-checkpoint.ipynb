# %%
import numpy as np
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import random as sr
from sklearn.random_projection import sparse_random_matrix as srmat
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
np.random.seed(1337)
from timeit import timeit
from plotters import kwargs

# %%
def nuclear_norm(A):
    return np.sum(np.linalg.svd(A)[1])

def simplex_projection(s):
    if np.sum(s) <=1 and np.alltrue(s >= 0):
        return s
    u = np.sort(s)[::-1]
    cssv = np.cumsum(u)
    rho = np.nonzero(u * np.arange(1, len(u)+1) > (cssv - 1))[0][-1]
    theta = (cssv[rho] - 1) / (rho + 1.0)
    return np.maximum(s-theta, 0)

def nuclear_projection(A):
    U, s, V = np.linalg.svd(A, full_matrices=False)
    s = simplex_projection(s)
    return U.dot(np.diag(s).dot(V))

def convergence_plot(fs1,fs2,gs1,gs2):
    plt.figure(figsize=(14,6))
    plt.subplot(121)
    plt.title('Convergence in objective')    
    plt.xlabel('Step')
    plt.ylabel('Error')
    plt.yscale('log')
    plt.plot(range(len(fs1)), fs1, **kwargs, label='Frank-Wolfe')
    plt.plot(range(len(fs2)), fs2, **kwargs, label='Projected-GD')    
    plt.legend()
    
    plt.subplot(122)
    plt.title('Convergence in domain')    
    plt.xlabel('Step')
    plt.yscale('log')
    plt.plot(range(len(gs1)), gs1, **kwargs, label='Frank-Wolfe')
    plt.plot(range(len(gs2)), gs2, **kwargs, label='Projected-GD')  
    plt.legend()
    plt.tight_layout()


def projected_gd(init, steps, grad, proj=lambda x: x):
    xs = [init]
    for step in steps:
        xs.append(proj(xs[-1] - step * grad(xs[-1])))
    return xs

def mc_objective(Y, O, X):

    return 0.5 * np.linalg.norm(Y-np.multiply(X, O), 'fro')**2

def mc_gradient(Y, O, X):

    return np.multiply(X, O) - Y

# %%
def frank_wolfe(initial, steps, oracle):

    xs = [initial]
    for step in steps:
        xs.append(xs[-1] + step*(oracle(xs[-1])-xs[-1]))
    return xs

def power_method(A, num_steps=10):

    m, n = A.shape
    x = np.random.normal(0,1, m)
    x /= np.linalg.norm(x)
    y = A.T.dot(x)
    y /= np.linalg.norm(y)
    for _ in range(num_steps):      
        x = A.dot(y)
        x /= np.linalg.norm(x)
        y = A.T.dot(x)
        y /= np.linalg.norm(y)        
    return x, y

def mc_oracle(Y, O, X):

    G = mc_gradient(Y, O, X)
    x, y = power_method(-G)
    return x.reshape((len(x), 1)).dot(y.reshape((1,len(y))))

# %%
n, k = 500, 15
U = np.random.normal(0, 1, (n, k))
U = np.linalg.qr(U)[0]
S = np.diag(np.random.uniform(0, 1, k))
S /= np.sum(S)
A = U.dot(S.dot(U.T))
O = np.random.randint(0,2, (n, n))
Y = np.multiply(A, O)

X0 = np.random.normal(0,1, (n,n))
X0 = nuclear_projection(X0.dot(X0.T))


oracle = lambda X: mc_oracle(Y, O, X)
steps = [2./(k+1.) for k in range(1, 200)]
Xfw = frank_wolfe(X0.copy(), steps, oracle)

objective = lambda X: mc_objective(Y, O, X)
gradient = lambda X: mc_gradient(Y, O, X)
Xp = projected_gd(X0.copy(), [0.2]*200, gradient, nuclear_projection)
convergence_plot([objective(X) for X in Xfw],[objective(X) for X in Xp],
                [np.linalg.norm(A-X, 'fro')**2 for X in Xfw],[np.linalg.norm(A-X, 'fro')**2 for X in Xp])

# %%
# _, S_opt, V = np.linalg.svd(A, full_matrices=False)
# _, Sfw, _ = np.linalg.svd(Xfw[-1], full_matrices=False)
# _, Sp, _ = np.linalg.svd(Xp[-1], full_matrices=False)

tsvd = TruncatedSVD(n_components=50, n_iter=10, random_state=42)
tsvd.fit(A)
S_opt = tsvd.singular_values_

tsvd = TruncatedSVD(n_components=50, n_iter=10, random_state=42)
tsvd.fit(Xfw[-1])
Sfw = tsvd.singular_values_

tsvd = TruncatedSVD(n_components=50, n_iter=10, random_state=42)
tsvd.fit(Xp[-1])
Sp = tsvd.singular_values_

plt.figure(figsize=(12,8))
plt.title('Largest 20 singular values of recovered solution')
plt.plot(range(20), np.sort(Sfw)[::-1][:20], 'o-', label='recovered(Frank-Wolfe)', **kwargs)
plt.plot(range(20), np.sort(Sp)[::-1][:20], 'o-', label='recovered(Projected-GD)', **kwargs)
plt.plot(range(20), np.sort(S_opt)[::-1][:20], 'o-', label='optimal', **kwargs)
plt.legend()

# %%
ts1 = []
ts2 = []
ns = [1000, 2000, 3000, 4000]
for n in ns:
    f = lambda: nuclear_projection(np.random.normal(0,1,(n, n)))
    ts1.append(timeit(f, number=1))
    Y = np.random.normal(0,1, (n, n))
    O = np.random.randint(0, 2, (n, n))
    X = np.random.normal(0,1, (n, n))
    f = lambda: mc_oracle(Y, O, X)
    ts2.append(timeit(f, number=1))

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Input dimension')
plt.ylabel('Time (s)')
plt.title('Projection vs linear optimization')
plt.plot(ns, ts1, label='projection', **kwargs)
plt.plot(ns, ts2, label='linear opt', **kwargs)
plt.legend()
